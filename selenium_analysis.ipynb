# %% [markdown]
# ## Identify Leads
#
# Query obituaries, divorce filings, tax delinquencies
# Reverse search names and current properties (need to find API)
# Query addresses in Redfin, grab data on estimated value and #bed/#baths, conduct RE analysis same as below
#
# ## Analyze large scale trends
#
# Pull from Redfin monthly data
# Pull in US census data for median income
# Analyze where housing prices are dropping month to month and rank most drastic price drops
# Analyze the best ratio between median household income (from census estimates) and average rent
#
#
# ## Analyze current house listings
# Scrape from redfin
#
# Calculate 20% down payment
#
# Query national mortgage rates for conventional 30 year loans
#
# Calculate Mortgage payments
#
# Calculate average prices per square foot
#
# ## Plot information
#
# Plot monthly analysis from redfin data
#
# Plot Map with best current listing deals
# Plot houses with best deals and associated financials (Address, Cash on Cash ROI, Cap Rate, Monthly/annual cash flow, estimated monthly payment, mortgage rate, down payment, estimated rent from Rentometer, )
#
# Plot house information from leads
#
# Send email when houses that are deals are found
#
# Uses conda environment re_analysis

# %%
us_zip_codes = {
        "Alabama": range(35004, 36925),
        "Alaska": range(99501 , 99950),
        "Arizona": range(85001,86556),
        "Arkansas": range(71601,72959),
        "California": range(90001,96162),
        "Colorado": range(80001,81658),
        "Connecticut": range(06001,06928),
        "Delaware":	range(19701,19980),
        "Florida":	range(32003,34997),
        "Georgia": range(30002,39901),
        "Hawaii": range(96701,96898),
        "Idaho": range(83201,83877),
        "Illinois": range(60001,62999),
        "Indiana": range(46001,47997),
        "Iowa": range(50001,52809),
        "Kansas": range(66002,67954),
        "Kentucky":	range(40003,42788),
        "Louisiana": range(70001,71497),
        "Maine": range(03901,04992),
        "Maryland": range(20588,21930),
        "Massachusetts": range(01001,05544),
        "Michigan": range(48001,49971),
        "Minnesota": range(55001,56763),
        "Mississippi": range(38601,39776),
        "Missouri": range(63001,65899),
        "Montana": range(59001,59937),
        "Nebraska": range(68001,69367),
        "Nevada": range(88901,89883),
        "New Hampshire": range(03031,03897),
        "New Jersey": range(07001,08989),
        "New Mexico": range(87001,88439),
        "New York": range(00501,14925),
        "North Carolina": range(27006,28909),
        "North Dakota": range(58001,58856),
        "Ohio": range(43001,45999),
        "Oklahoma": range(73001,74966),
        "Oregon": range(97001,97920),
        "Pennsylvania": range(15001,19640),
        "Rhode Island": range(02801,02940),
        "South Carolina": range(29001,29945),
        "South Dakota":	range(57001,57799),
        "Tennessee": range(37010,38589),
        "Texas": range(73301,88595),
        "Utah": range(84001,84791),
        "Vermont": range(05001,05907),
        "Virginia": range(20101,24658),
        "Washington": range(98001,99403),
        "West Virginia": range(24701,26886),
        "Wisconsin": range(53001,54990),
        "Wyoming": range(82001,83414)
        }

us_cities = {}

us_neighborhoods = {}

# Sources (current as of 2022)
# https://www.bankrate.com/real-estate/property-tax-by-state/#by-state 
# https://wallethub.com/edu/states-with-the-highest-and-lowest-property-taxes/11585
state_property_tax_rates = {
    "Alabama": .0041,
    "Alaska": .0119,
    "Arizona": .0066,
    "Arkansas": .0062,
    "California": .0076,
    "Colorado": .0051,
    "Connecticut": .0214,
    "Delaware":	.0057,
    "Florida":	.0089,
    "Georgia": .0092,
    "Hawaii": .0028,
    "Idaho": .0069,
    "Illinois": .0227,
    "Indiana": .0085,
    "Iowa": .0157,
    "Kansas": .0141,
    "Kentucky":	.0086,
    "Louisiana": .0055,
    "Maine": .0136,
    "Maryland": .0109,
    "Massachusetts": .0123,
    "Michigan": .0154,
    "Minnesota": .0112,
    "Mississippi": .0081,
    "Missouri": .0097,
    "Montana": .0084,
    "Nebraska": .0173,
    "Nevada": .0060,
    "New Hampshire": .0218,
    "New Jersey": .0249,
    "New Mexico": .0080,
    "New York": .0172,
    "North Carolina": .0084,
    "North Dakota": .0098,
    "Ohio": .0156,
    "Oklahoma": .0090,
    "Oregon": .0097,
    "Pennsylvania": .0158,
    "Rhode Island": .0163,
    "South Carolina": .0057,
    "South Dakota":	.0131,
    "Tennessee": .0071,
    "Texas": .0180,
    "Utah": .0063,
    "Vermont": .0190,
    "Virginia": .0082,
    "Washington": .0098,
    "West Virginia": .0058,
    "Wisconsin": .01858,
    "Wyoming": .0061
}

# %%
import pandas as pd

test_zips = pd.read_csv("simplemaps_uszips_basicv1.81/uszips.csv")

test_zips.head()

# %%
import shapefile as shp  # Requires the pyshp package
import matplotlib.pyplot as plt

sf = shp.Reader(r"C:\Users\ntech\OneDrive\Documents\Coding\Real__Estate_Analytics\tl_2022_us_zcta520\tl_2022_us_zcta520.shp")

plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ShapefileException                        Traceback (most recent call last)
# <ipython-input-8-0620778bc5ba> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 sf = shp.Reader("tl_2022_us_zcta520\tl_2022_us_zcta520.shp")
#       5
#       6 plt.figure()
#
# c:\Users\ntech\anaconda3\envs\re_analysis\lib\site-packages\shapefile.py in __init__(self, *args, **kwargs)
#    1046                     # Local file path to a shapefile
#    1047                     # Load and exit early
# -> 1048                     self.load(path)
#    1049                     return
#    1050
#
# c:\Users\ntech\anaconda3\envs\re_analysis\lib\site-packages\shapefile.py in load(self, shapefile)
#    1191             self.load_dbf(shapeName)
#    1192             if not (self.shp or self.dbf):
# -> 1193                 raise ShapefileException("Unable to open %s.dbf or %s.shp." % (shapeName, shapeName))
# ...

# %% [markdown]
# Data comes from
#
# https://www2.census.gov/geo/tiger/TIGER2022/

# %%
# https://community.plotly.com/t/plot-a-shapefile-shp-in-a-choropleth-chart/27850

import geopandas as gpd
import json

geodf = gpd.read_file(r'C:\Users\ntech\OneDrive\Documents\Coding\Real__Estate_Analytics\tl_2022_us_zcta520\tl_2022_us_zcta520.shp')

geodf.to_file(r"C:\Users\ntech\OneDrive\Documents\Coding\Real__Estate_Analytics\tl_2022_us_zcta520\tl_2022_us_zcta520.json", driver = "GeoJSON")

# %%
with open(r"C:\Users\ntech\OneDrive\Documents\Coding\Real__Estate_Analytics\tl_2022_us_zcta520\tl_2022_us_zcta520.json") as geofile:
    j_file = json.load(geofile)

i=1
for feature in j_file["features"]:
    feature ['id'] = str(i).zfill(2)
    i += 1

# %%
geodf.head()
# Out:
#   ZCTA5CE20 GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20  ALAND20  AWATER20  \
# 0     47236   47236        B5   G6350          S  1029063         0
# 1     47870   47870        B5   G6350          S     8830         0
# 2     47851   47851        B5   G6350          S    53326         0
# 3     47337   47337        B5   G6350          S   303089         0
# 4     47435   47435        B5   G6350          S    13302         0
#
#     INTPTLAT20    INTPTLON20  \
# 0  +39.1517426  -085.7252769
# 1  +39.3701518  -087.4735141
# 2  +39.5735839  -087.2459559
# 3  +39.8027537  -085.4372850
# 4  +39.2657557  -086.2951577
#
#                                             geometry
# 0  POLYGON ((-85.73410 39.15597, -85.72794 39.156...
# 1  POLYGON ((-87.47414 39.37016, -87.47409 39.370...
# 2  POLYGON ((-87.24769 39.57450, -87.24711 39.574...
# 3  POLYGON ((-85.44357 39.80328, -85.44346 39.803...
# 4  POLYGON ((-86.29592 39.26547, -86.29592 39.266...

# %%
#https://plotly.com/python/mapbox-county-choropleth/?_ga=2.132247118.1321867310.1669320955-1319191312.1668946150

import plotly.express as px

# Load 
fig = px.choropleth_mapbox(geodf, locations='GEOID20',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                           zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                           opacity=0.5,
                          )
'''
fig = px.choropleth_mapbox(geodf, geojson=counties, locations='fips', color='unemp',
                           color_continuous_scale="Viridis",
                           range_color=(0, 12),
                           mapbox_style="carto-positron",
                           zoom=3, center = {"lat": 37.0902, "lon": -95.7129},
                           opacity=0.5,
                           labels={'unemp':'unemployment rate'}
                          )
'''                          
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
from bs4 import BeautifulSoup
import random
import requests
from fake_useragent import UserAgent
from urllib.request import Request, urlopen

ua = UserAgent()
userAgent = ua.random

# Find a random proxy to use in the request to obscure source ip address
# https://stackoverflow.com/questions/38785877/spoofing-ip-address-when-web-scraping-python
proxies = []
proxies_req = Request('https://www.sslproxies.org/')
proxies_req.add_header('User-Agent', userAgent)
proxies_doc = urlopen(proxies_req).read().decode('utf8')
soup = BeautifulSoup(proxies_doc, 'html.parser')
proxies_table = soup.find("table", class_="table table-striped table-bordered")

# Save proxies in the array
for row in proxies_table.tbody.find_all('tr'):
    proxies.append({
        'ip':   row.find_all('td')[0].string,
        'port': row.find_all('td')[1].string
    })


print(proxies)
# Out:
# [{'ip': '163.116.158.118', 'port': '8081'}, {'ip': '46.60.251.51', 'port': '9091'}, {'ip': '163.116.248.45', 'port': '808'}, {'ip': '163.116.248.46', 'port': '808'}, {'ip': '80.252.5.34', 'port': '7001'}, {'ip': '163.116.177.48', 'port': '808'}, {'ip': '115.68.221.147', 'port': '80'}, {'ip': '163.116.177.32', 'port': '808'}, {'ip': '196.15.213.235', 'port': '3128'}, {'ip': '198.59.191.234', 'port': '8080'}, {'ip': '151.248.115.5', 'port': '3128'}, {'ip': '34.66.5.144', 'port': '8888'}, {'ip': '94.237.3.45', 'port': '8086'}, {'ip': '163.116.158.25', 'port': '8081'}, {'ip': '163.116.248.42', 'port': '808'}, {'ip': '159.192.249.98', 'port': '8080'}, {'ip': '163.116.177.31', 'port': '808'}, {'ip': '46.60.251.52', 'port': '9091'}, {'ip': '46.60.251.50', 'port': '9091'}, {'ip': '190.61.88.147', 'port': '8080'}, {'ip': '163.116.248.39', 'port': '808'}, {'ip': '222.234.220.170', 'port': '3128'}, {'ip': '51.159.115.233', 'port': '3128'}, {'ip': '47.241.165.133', 'port': '443'}, {'ip': '129.21
# ...

# %%
from bs4 import BeautifulSoup
import random
import requests
from fake_useragent import UserAgent
from urllib.request import Request, urlopen
from IPython.core.display import clear_output

############################ Obfuscation ################################3

# Create a random user agent to use in request to obscure browser
ua = UserAgent()
userAgent = ua.random

# Find a random proxy to use in the request to obscure source ip address
# https://stackoverflow.com/questions/38785877/spoofing-ip-address-when-web-scraping-python

# Grab proxies from website
# Need to add try except for grabbing proxy and use regular ip address if proxies not working

proxies = []
delete_proxies = []
proxies_req = Request('https://www.sslproxies.org/')
proxies_req.add_header('User-Agent', userAgent)
proxies_doc = urlopen(proxies_req).read().decode('utf8')
soup = BeautifulSoup(proxies_doc, 'html.parser')
proxies_table = soup.find("table", class_="table table-striped table-bordered")

# Save proxies in array
for row in proxies_table.tbody.find_all('tr'):
    proxies.append({
        'ip':   row.find_all('td')[0].string,
        'port': row.find_all('td')[1].string
    })

# Retrieve a random index proxy (we need the index to delete it if not working)
#proxy_index = random.randint(0, len(proxies) - 1)
#proxy = proxies[proxy_index]


# Iterate through proxies and test if they work, delete those that don't work
for n in range(0, len(proxies)):
    proxy_index = n
    proxy = proxies[n]
    req = Request('http://icanhazip.com')
    req.set_proxy(proxy['ip'] + ':' + proxy['port'], 'http')

    # Make the test call, print what ip address the website sees
    try:
        my_ip = urlopen(req).read().decode('utf8')
        print('#' + str(n) + ': ' + my_ip)
        clear_output(wait = True)
    except: # If error, add to list of proxies to delete
        delete_proxies.append(n)
        print('Proxy ' + proxy['ip'] + ':' + proxy['port'] + ' deleted.')

for i in sorted(delete_proxies, reverse=True):
    del proxies[i]
# Out:
# Proxy 213.230.71.184:3128 deleted.
# Proxy 51.79.50.31:9300 deleted.
# Proxy 87.245.186.149:8090 deleted.

# %%
############################ USER INPUT #############################

# Set url for desired search in redfin
# Update to possibly iterate through zip code or neighborhood through entire us, query with different proxy and user agent each time
url = "https://www.redfin.com/city/16904/CA/San-Diego/filter/viewport=33.25527:32.98095:-116.97292:-117.32517,no-outline"

# Set up iteration through list of every US city or every zip code
#headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36', 'Accept': 'application/json'}

zipcode = "92082"

########################## GET Request ###############################
# Need to add try except for if proxy or something else stops working

# Set request headers 

# Mobile test
#userAgent = 'Mozilla/5.0 (iPhone; CPU iPhone OS 10_3 like Mac OS X) AppleWebKit/602.1.50 (KHTML, like Gecko) CriOS/56.0.2924.75 Mobile/14E5239e Safari/602.1'
headers = {'User-Agent': userAgent}

# Set proxy to use
proxy = random.choice(proxies)

# Set request parameters
params = {}

# Set URL
#url = "https://www.redfin.com/zipcode/" + zipcode + "/filter/property-type=house+multifamily" # This adds multifamily
url = "https://www.redfin.com/zipcode/" + zipcode + "/filter/property-type=house" # Only searches single family

# Query zip code
#https://www.redfin.com/stingray/do/query-location?al=1&lat=33.257295&lng=-116.996475&location=92069&market=socal&num_homes=1000&ooa=true&v=2
# Get request

# Query city
# https://www.redfin.com/stingray/do/query-location?al=1&lat=33.18197500000001&lng=-117.15870500000001&location=san%20diego&market=socal&num_homes=1000&ooa=true&v=2

# Send get request
r = requests.get(url=url, params=params, headers=headers, proxies=proxy)

soup = BeautifulSoup(r.text)

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Server: phantom-8 -->
#   <!-- Time generated: Thu Jan 05 2023 09:50:24 GMT-0800 (Pacific Standard Time) -->
#   <script>
#    (function(a){window.__reactServerOnClickHandler=function(i){(a[i]=a[i]||[]).push(new Date)}})(window.__reactServerUnhandledEvents={})
#   </script>
#   <script>
#    /*! LAB.js (LABjs :: Loading And Blocking JavaScript)
#     v2.0.3 (c) Kyle Simpson
#     MIT License
# */
# ...

# %%
import re
import json

home_list = soup.select('div[id*="MapHomeCard_"]')

for home in home_list:
    
    #home = home_list[0]

    # Get address
    # <span class="collapsedAddress primaryLine" data-rf-test-id="abp-streetLine">
    address = home.find_all(class_="collapsedAddress primaryLine")[0].text
    address_parts = json.loads(home.find('script', type="application/ld+json").text)[0]
    street = address_parts['address']['streetAddress']
    city = address_parts['address']['addressLocality']
    state = address_parts['address']['addressRegion']
    zipcode = address_parts['address']['postalCode']

    print(address)
    print(address_parts)
    print("Street: " + street)
    print("City: " + city)
    print("State: " + state)
    print("Zipcode: " + zipcode)
    print('\n\n')
# Out:
# 27822 Silo Ln, Valley Center, CA 92082
# {'@context': 'http://schema.org', 'name': '27822 Silo Ln, Valley Center, CA 92082', 'url': '/CA/Valley-Center/27822-Silo-Ln-92082/home/172049790', 'address': {'@type': 'PostalAddress', 'streetAddress': '27822 Silo Ln', 'addressLocality': 'Valley Center', 'addressRegion': 'CA', 'postalCode': '92082', 'addressCountry': 'US'}, 'numberOfRooms': '4', '@type': 'SingleFamilyResidence'}
# Street: 27822 Silo Ln
# City: Valley Center
# State: CA
# Zipcode: 92082
#
#
#
# 30460 Anthony Rd, Valley Center, CA 92082
# {'@context': 'http://schema.org', 'name': '30460 Anthony Rd, Valley Center, CA 92082', 'url': '/CA/Valley-Center/30460-Anthony-Rd-92082/home/3143229', 'address': {'@type': 'PostalAddress', 'streetAddress': '30460 Anthony Rd', 'addressLocality': 'Valley Center', 'addressRegion': 'CA', 'postalCode': '92082', 'addressCountry': 'US'}, 'numberOfRooms': '3', '@type': 'SingleFamilyResidence'}
# Street: 30460 Anthony Rd
# City: Valley Center
# ...

# %%
from re import sub
from decimal import Decimal
import re

# If return is mobile from mobile user agent, else normal request response

if len(soup.select('div[data-rf-paint-id="mobile-homecard-list"]')) > 0:
    MOBILE = True
else:
    MOBILE = False
    
if MOBILE:
    home_list = soup.find_all(class_='mobileListHomeCard mobileListHomeCardV2')
else:
    home_list = soup.select('div[id*="MapHomeCard_"]')

# Iterate through homes
home_data = {}
n=0

for home in home_list:
    
    #home = home_list[0]

    # Get address
    # <span class="collapsedAddress primaryLine" data-rf-test-id="abp-streetLine">
    address = home.find_all(class_="collapsedAddress primaryLine")[0].text
    address_parts = json.loads(home.find('script', type="application/ld+json").text)[0]
    street = address_parts['address']['streetAddress']
    city = address_parts['address']['addressLocality']
    state = address_parts['address']['addressRegion']
    zipcode = address_parts['address']['postalCode']

    # Get price
    # class="homecardV2Price"
    price = home.find_all(class_="homecardV2Price")[0].text
    price =  int(Decimal(sub(r'[^\d\-.]', '', price)))
    

    # Get beds, baths, sq ft
    # <div class="stats">
    stats = home.find_all(class_="stats")

    beds = int(re.sub("[^0-9]", "", stats[0].text))
    baths = float(re.findall(r"[-+]?(?:\d*\.\d+|\d+)", stats[1].text)[0]) 
    sq_ft = int(re.sub("[^0-9]", "", stats[2].text))
    

    # Get description
    # <div class="remarks withTitle">
    #         <p>
    #          92082 Home for Sale:
    #         </p>
    #         <p>
    descr_el = home.find_all(class_="remarks withTitle")
    descr = descr_el[0].find_all('p')[1].text

    # Get images
    #<a class="slider-item" data-rf-test-id="slider-item-0" data-rf-test-name="basic-card-photo" href="/CA/Valley-Center/31371-Justin-Pl-92082/home/3153655" style="transform:translateX(0px)" target="_self">
    #       <img alt="Photo of 31371 Justin Pl, Valley Center, CA 92082" class="homecard-image" fetchpriority="high" height="100%" src="https://ssl.cdn-redfin.com/photo/48/mbphoto/376/genMid.220028376_0.jpg" style="width:100%;height:100%;object-fit:cover;object-position:center" title="31371 Justin Pl, Valley Center, CA 92082" width="100%"/>
    
    '''
    Need to add images
    images = home.find_all(class_="homecard-image")
    image_urls = []
    for element in images:
        print(element)
        image_urls.append(element["src"])
    '''

    '''Need to grab lat/long from each listing to use in plotting on map'''

    # Get listing URL, navigate to the listing, grab redfin rent estimate
    for link in home.find_all("a"):
        try:
            link_bool = (address == link["title"])
            home_link = "https://www.redfin.com/" + link["href"]
        except:
            continue

    # Calculate price per square foot

    price_sq_ft = round(price/sq_ft, 2)

    home_data[n] = {"address": address, "street": street, "city": city, "state": state, "zipcode": zipcode, "price": price, "beds": beds, "baths": baths, "sq_ft": sq_ft, "price_sq_ft": price_sq_ft, "home_link": home_link, "description":descr}

    n+=1

    home_df = pd.DataFrame.from_dict(home_data, orient='index')

print(json.dumps(home_data, indent=4))
# Out:
# {
#     "0": {
#         "address": "27822 Silo Ln, Valley Center, CA 92082",
#         "street": "27822 Silo Ln",
#         "city": "Valley Center",
#         "state": "CA",
#         "zipcode": "92082",
#         "price": 743803,
#         "beds": 4,
#         "baths": 3.0,
#         "sq_ft": 2262,
#         "price_sq_ft": 328.83,
#         "home_link": "https://www.redfin.com//CA/Valley-Center/27822-Silo-Ln-92082/home/172049790",
# ...

# %%
import pandas as pd 

home_df = pd.DataFrame.from_dict(home_data, orient='index')

home_df
# Out:
#                                             address                  street  \
# 0            27822 Silo Ln, Valley Center, CA 92082           27822 Silo Ln
# 1         30460 Anthony Rd, Valley Center, CA 92082        30460 Anthony Rd
# 2       13019 Westrose Way, Valley Center, CA 92082      13019 Westrose Way
# 3     28327 Farm Creek Way, Valley Center, CA 92082    28327 Farm Creek Way
# 4     28427 Farm Creek Way, Valley Center, CA 92082    28427 Farm Creek Way
# 5        16390 DIA DEL SOL, Valley Center, CA 92082       16390 DIA DEL SOL
# 6         28020 Harvest Ct, Valley Center, CA 92082        28020 Harvest Ct
# 7         30531 Andreen Rd, Valley Center, CA 92082        30531 Andreen Rd
# 8         28032 Harvest Ct, Valley Center, CA 92082        28032 Harvest Ct
# 9       13318 Cultivate Ct, Valley Center, CA 92082      13318 Cultivate Ct
# 10     27928 Evergreen Way, Valley Center, CA 92082     27928 Evergreen Way
# ...

# %%
# Test with census rental estimates

def address_geocode(street, city, state, zipcode):
    # returns geocoding information for every address to compare rent data to

    params = {'benchmark':'Public_AR_Current', 'vintage':'Current_Current', 'street':street, 'city':city, 'state':state, 'zip': str(zipcode), 'format':'json', 'layers':'all'}
    url = 'https://geocoding.geo.census.gov/geocoder/{0}/{1}?'.format('geographies','address')
    response = requests.get(url=url, params=params)
    geographies = response.json()

    print(geographies)
    
    county = geographies["result"]["addressMatches"][0]["geographies"]["Counties"][0]["COUNTY"]
    county_sub = geographies["result"]["addressMatches"][0]["geographies"]["County Subdivisions"][0]["COUSUB"]
    tract = geographies["result"]["addressMatches"][0]["geographies"]["Census Tracts"][0]["TRACT"]
    state_code = geographies["result"]["addressMatches"][0]["geographies"]["States"][0]["STATE"]

    #geocode = {"county":county, "county_sub":county_sub, "tract":tract, "street":street, "city":city, "state":state_code, "zipcode":zipcode}

    #return geocode

    return county, county_sub, tract, state_code

# %%
home_df[['county', 'county_sub', 'tract', 'state_code']] = home_df.apply(lambda x: address_geocode(street=x['street'], city=x['city'], state=x['state'], zipcode=x['zipcode']), axis=1)

home_df
# Out:
# 27822 Silo Ln
# Valley Center
# CA
# 92082
# {'result': {'input': {'address': {'zip': '92082', 'city': 'Valley Center', 'street': '27822 Silo Ln', 'state': 'CA'}, 'vintage': {'isDefault': True, 'id': '4', 'vintageName': 'Current_Current', 'vintageDescription': 'Current Vintage - Current Benchmark'}, 'benchmark': {'isDefault': True, 'benchmarkDescription': 'Public Address Ranges - Current Benchmark', 'id': '4', 'benchmarkName': 'Public_AR_Current'}}, 'addressMatches': []}}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-45-d295104963e3> in <module>
# ----> 1 home_df[['county', 'county_sub', 'tract', 'state_code']] = home_df.apply(lambda x: address_geocode(street=x['street'], city=x['city'], state=x['state'], zipcode=x['zipcode']), axis=1)
#       2
#       3 home_df
#
# ...

# %%
home_df
# Out:
#                                             address                  street  \
# 0            27822 Silo Ln, Valley Center, CA 92082           27822 Silo Ln
# 1         30460 Anthony Rd, Valley Center, CA 92082        30460 Anthony Rd
# 2       13019 Westrose Way, Valley Center, CA 92082      13019 Westrose Way
# 3     28327 Farm Creek Way, Valley Center, CA 92082    28327 Farm Creek Way
# 4     28427 Farm Creek Way, Valley Center, CA 92082    28427 Farm Creek Way
# 5        16390 DIA DEL SOL, Valley Center, CA 92082       16390 DIA DEL SOL
# 6         28020 Harvest Ct, Valley Center, CA 92082        28020 Harvest Ct
# 7         30531 Andreen Rd, Valley Center, CA 92082        30531 Andreen Rd
# 8         28032 Harvest Ct, Valley Center, CA 92082        28032 Harvest Ct
# 9       13318 Cultivate Ct, Valley Center, CA 92082      13318 Cultivate Ct
# 10     27928 Evergreen Way, Valley Center, CA 92082     27928 Evergreen Way
# ...

# %%
# Test to get redfin rental estimate

# Can't do it because not every listing has a redfin rental estimate

listing = requests.get(url=home_data[0]["home_link"], params=params, headers=headers, proxies=proxy)

listing_soup = BeautifulSoup(listing.text)

# %%
# Calculate mortgage and other costs

##################### USER INPUT ######################
mortage_rate = .007
down_payment = .2
##################### END USER INPUT #####################

for key in home_data:
    home_data[key]["address"]

# %%
# Compare home prices to average trends from Redfin 
# find the homes that are lower than the trends in their zip code
# Lower than the median price per square foot

# %%
# Set test values for querying rent prices

test_address = home_data[0]["address"]

test_bed = home_data[0]["beds"]

test_baths = home_data[0]["baths"]

test_address, test_bed, test_baths
# Out:
# ('31371 Justin Pl, Valley Center, CA 92082', 4, 2.5)

# %%
# Grab rentometer value from the quickview using webscraping

# Can't get to work because I think the URL needs a nonce and I need to login for unlimited queries
# Try using requests session to authenticate and generate a nonce
# https://gist.github.com/jdembowski/403400d6093dc1d2e5fc846ea10ee375
# https://www.google.com/search?q=requests+session+login+data&rlz=1C1CHBF_enUS881US881&oq=requests+session+login+data&aqs=chrome..69i57j0i22i30l2j0i10i15i22i30j0i22i30l2j0i390l4.5829j0j7&sourceid=chrome&ie=UTF-8#fpstate=ive&vld=cid:7f0afe94,vid:wMf7LJn0k4U

# https://www.rentometer.com/analysis/5-bed/31515-larga-vista-valley-center-ca/rNO_s1cSDPQ/quickview

# https://www.rentometer.com/analysis/5-bed/31515-larga-vista-valley-center-ca/ZJ-X-G4x1s0/quickview

import hashlib

rm_url = "https://www.rentometer.com/"
rm_login_url = "https://www.rentometer.com/accounts/sign_in"
username = "homefreerealestate@gmail.com"
password = "VaL872ziMe4t"

#rm_redirect = "https://www.rentometer.com/"

rm_session = requests.session()

# Need to submit get request first to establish session
init_rm=rm_session.get(rm_url) #, headers=headers, proxies=proxy)

'''
if 'csrftoken' in init_rm.cookies:
    # Django 1.6 and up
    csrftoken = init_rm.cookies['csrftoken']
else:
    # older versions
    csrftoken = init_rm.cookies['csrf']
'''
'''
login_data={
    'user[email]':username, 'user[password]': hashlib.md5(bytes(password, encoding='utf8')), 'submit': 'Sign In',
    'redirect_to':rm_redirect
}
'''

payload = {
    'user[email]':username,
    'user[password]': hashlib.md5(bytes(password, encoding='utf8')).hexdigest()
}

'''
headers = {
    Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9
    Accept-Encoding: gzip, deflate, br
    Accept-Language: en-US,en;q=0.9
    Cache-Control: no-cache
    Connection: keep-alive
    Content-Length: 759
    Content-Type: application/x-www-form-urlencoded
    Cookie: ahoy_visitor=54938c3f-9ac6-4672-ae47-25d857a24771; __stripe_mid=7ba9fe01-9818-4454-82ea-92aae4348131e275e1; __zlcmid=1CZlJrahLp3rZCO; ahoy_visit=b5f9813a-81f8-4ea6-ba20-e5e188f021a5; __stripe_sid=978441ea-b8cd-4c0d-8d7b-2e267ce9162991a3bb; _rentometer2_session=1xtxkfL7PwFBaScsG8pQsb8cKgFKbqbkoDN9oJTG1N8rkybtNO5S1ZhgcfTentUrumoBjRxECqaT5LeyQUjAq0n20zSzw4JkG%2BMaX%2BMeMPWi9KbBQ9Grk8SPFZkxqdf1aLJNLM3d8pOF2sVyxvsyrRIrIdyYvNZGdHKU3xbHOvP%2B9sFv%2BnvhcdWNpIOqcUtsdDDY8xnQK4zLsNJd1F1vZ2cNyUI9Axk%2BQC%2Bt32ctJIigLsIzP4dOtlRXCJP7e5eqhyjXhG%2BpTkpo6Pfx8eya9iX73z5zvQhsXlyE6cC7h3lxPhSzOEgPZC9kMeRNEMOA6LgkGed4mTXpPbkk2GIArf67DXLhz4lM2PDopnb99eet4LUjhRnoOHTDZjxczhmMirkLwqY1X37YiRfWE0SVm8Q0CJ5tkJNxI7oKcX40v6Bn4qsVSjRHDO%2BOeuy25gGRI%2F2ge1%2FaWUsQSdkPiMY%3D--6qJM1B2TmZ%2B7fs1d--Op00wAwxiUcJ9egdYrMl3Q%3D%3D
    dnt: 1
    Host: www.rentometer.com
    Origin: https://www.rentometer.com
    Pragma: no-cache
    Referer: https://www.rentometer.com/accounts/sign_in
    sec-ch-ua: "Google Chrome";v="107", "Chromium";v="107", "Not=A?Brand";v="24"
    sec-ch-ua-mobile: ?0
    sec-ch-ua-platform: "Windows"
    Sec-Fetch-Dest: document
    Sec-Fetch-Mode: navigate
    Sec-Fetch-Site: same-origin
    Sec-Fetch-User: ?1
    sec-gpc: 1
    Upgrade-Insecure-Requests: 1
    User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36

}
'''
#rm=rm_session.post(rm_login_url, data=login_data, headers=headers, proxies=proxy)
#rm=rm_session.post(rm_login_url, auth=(username, hashlib.md5(bytes(password, encoding='utf8')).hexdigest()), headers=headers, proxies=proxy)
rm=rm_session.post(rm_login_url, data=payload) #, headers=headers, proxies=proxy)

with open('index.html', 'w') as file:
    file.write(rm.text)
    
print(rm.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <title>Rentometer: House and Apartment Rental Rate Comps</title>
#     <meta name="description" content="Paying too much for rent or charging too little? Get rental comps and find apartments with Rentometer."/>
#     <meta name="keywords" content="rental comps, house rental comparisons, apartment rental comparisons, rent rates"/>
#     <meta name="referrer" content="origin-when-cross-origin">
#
#     <meta property="og:title" content="Rentometer: House and Apartment Rental Rate Comps" />
#     <meta property="og:description" content="Paying too much for rent or charging too little? Get rental comps and find apartments with Rentometer." />
#     <meta property="og:type" content="website" />
#     <meta property="og:url" content="https://www.rentometer.com/accounts/sign_in" />
# ...

# %%
# Query Rentometer API for estimated rent price

#################### Rentometer API Rent Estimate #########################

RENTOMETER_API_KEY = "N1bzLReReGWNwNuETVQYYg"

#rentometer_url_auth = 'https://www.rentometer.com/api/v1/auth?api_key=' + RENTOMETER_API_KEY
#rentometer_url_rent = "https://www.rentometer.com/api/v1/summary?api_key=RENTOMETER_API_KEY&address=15%20broad%20st.,%20boston,%20ma&bedrooms=2&baths=1.5%2B&building_type=house"

rentometer_url_rent = "https://www.rentometer.com/api/v1/summary?"

if test_baths > 1:
    test_baths = "1.5"
elif test_baths < 1:
    test_baths = ""

params = (
    ("api_key", RENTOMETER_API_KEY),
    ("address", test_address),
    ("bedrooms", str(test_bed)),
    ("baths", test_baths),
    ("building_type", "house"),
)

rent_estimate = requests.get(url=rentometer_url_rent, params=params)

rent_estimate = json.loads(rent_estimate.text)

rent_estimate
# Out:
# '{"address":"31371 Justin Pl, Valley Center, CA 92082","latitude":"33.280714","longitude":"-117.014996","bedrooms":4,"baths":"1.5+","building_type":"House","look_back_days":365,"mean":4234,"median":4050,"min":3400,"max":5300,"percentile_25":3765,"percentile_75":4703,"std_dev":695,"samples":6,"radius_miles":5.0,"quickview_url":"https://www.rentometer.com/analysis/4-bed/31371-justin-pl-valley-center-ca-92082/irsGGitLaXg/quickview","credits_remaining":499,"token":"irsGGitLaXg","links":[{"rel":"request pro report","href":"/api/v1/request_pro_report?api_key=N1bzLReReGWNwNuETVQYYg&token=irsGGitLaXg"}]}'

# %%
# Realty Mole Rent Estimate
# https://rapidapi.com/moneals/api/rent-estimate/
# Pricing is expensive for mass analytics

# Not working, can't find every home sent to API

import requests

url = "https://realtymole-rental-estimate-v1.p.rapidapi.com/rentalPrice"

headers = {
	"X-RapidAPI-Key": "0ae669d71cmsh21253ca9f0c84f5p17b510jsn212cb0b7afa9",
	"X-RapidAPI-Host": "realtymole-rental-estimate-v1.p.rapidapi.com"
}

# Iterate through homes and query rent estimate, save for analysis

for id in home_data:
    home = home_data[id]

    try:
        querystring = {"address":home["address"],"propertyType":"Single Family","bedrooms":home["beds"],"bathrooms":home["baths"],"squareFootage":home["sq_ft"],"compCount":"10"}

        realty_mole_response = requests.request("GET", url, headers=headers, params=querystring)

        realty_mole_rent = json.loads(realty_mole_response.text)

        # Modify home data with rent estimates
        home_data[id]["rent_estimate"] = realty_mole_rent["rent"]
        home_data[id]["rent_estimate_low"] = realty_mole_rent["rentRangeLow"]
        home_data[id]["rent_estimate_high"] = realty_mole_rent["rentRangeHigh"]
    except:
        # Couldn't locate home address
        home_data[id]["rent_estimate"] = 0
        home_data[id]["rent_estimate_low"] = 0
        home_data[id]["rent_estimate_high"] = 0

print(json.dumps(home_data, indent=4))
# Out:
# {
#     "0": {
#         "address": "31371 Justin Pl, Valley Center, CA 92082",
#         "price": 1050000,
#         "beds": 4,
#         "baths": 2.5,
#         "sq_ft": 2611,
#         "price_sq_ft": 402.14,
#         "home_link": "https://www.redfin.com//CA/Valley-Center/31371-Justin-Pl-92082/home/3153655",
#         "description": "The home you've been looking for has arrived Justin time! . .. You will simply love this single-level home located on a private cul-de-sac street in the very desirable Silver Oaks community. Sensible, flowing floor plan with 2611 sf of living space, 4 bedrooms, 2.5 baths, fireplaces in the Family Room and Master Bedroom. Resort-style swimming pool and spa. Large covered concrete patio. Fully fenced and gated. Horse facilities include tack/feed shed, round pen and four corrals with water feeders. Large pad for RV. Four sheds for additional storage.",
#         "rent_estimate": 4116.2,
#         "rent_estimate_low": 3378.42,
# ...

# %%
querystring = {"address":"13409 Rosie Ct, Valley Center, CA 92082","propertyType":"Single Family","bedrooms":home["beds"],"bathrooms":home["baths"],"squareFootage":home["sq_ft"],"compCount":"10"}

realty_mole_response = requests.request("GET", url, headers=headers, params=querystring)

print(realty_mole_response.text)
# Out:
# Error trying to locate address: 13409 Rosie Ct, Valley Center, CA 92082

# %%
print(json.dumps(home_data, indent=4))
# Out:
# {
#     "0": {
#         "address": "31371 Justin Pl, Valley Center, CA 92082",
#         "price": 1050000,
#         "beds": 4,
#         "baths": 2.5,
#         "sq_ft": 2611,
#         "price_sq_ft": 402.14,
#         "home_link": "https://www.redfin.com//CA/Valley-Center/31371-Justin-Pl-92082/home/3153655",
#         "description": "The home you've been looking for has arrived Justin time! . .. You will simply love this single-level home located on a private cul-de-sac street in the very desirable Silver Oaks community. Sensible, flowing floor plan with 2611 sf of living space, 4 bedrooms, 2.5 baths, fireplaces in the Family Room and Master Bedroom. Resort-style swimming pool and spa. Large covered concrete patio. Fully fenced and gated. Horse facilities include tack/feed shed, round pen and four corrals with water feeders. Large pad for RV. Four sheds for additional storage.",
#         "rent_estimate": 4116.2,
#         "rent_estimate_low": 3378.42,
# ...

# %%
# Analyze Deal, calculate ROI, CAP rate, etc

# %%
# Other possible real estate analytics

# Mashvisor is another option
# https://rapidapi.com/mashvisor-team/api/mashvisor/

# Realty Mole
# https://rapidapi.com/realtymole/api/realty-mole-property-api/
